# %% [markdown]
# # Strip Plot

# %% [markdown]
# A strip plot is a type of categorical scatter plot where individual data points are displayed along a single axis, typically representing a categorical variable. It can be useful for visualizing the distribution of values within different categories.

# %% [markdown]
# ## Loading the required libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /home/chaitanya/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# ### Loading the dataset

# %%
data = sns.load_dataset("tips")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Plotting the stripplot

# %%
plt.figure(figsize=(20, 10))
sns.stripplot(x="day", y="total_bill", data=data)
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.stripplot(x="day", y="total_bill", data=data, hue="sex")
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.stripplot(x="day", y="total_bill", data=data, hue="sex", palette="jet_r")
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.stripplot(x="day", y="total_bill", data=data, hue="sex", palette="rocket", linewidth=0.75)
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.stripplot(x="day", y="total_bill", data=data, hue="sex", palette="rocket", linewidth=0.75, jitter=1)
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.stripplot(x="day", y="total_bill", data=data, hue="sex", palette="flag", linewidth=0.75, size=7.5)
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.stripplot(x="day", y="total_bill", data=data, hue="sex", palette="flag", linewidth=0.75, size=7.5, marker="*")
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.stripplot(x="total_bill", data=data, marker="*")
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.stripplot(y="total_bill", data=data, marker="*")
plt.show()
