# %% [markdown]
# # Violin Plot

# %% [markdown]
# A violin plot is a data visualization that combines aspects of a box plot and a kernel density plot. It provides insights into the distribution and probability density of the data across different levels of a categorical variable.

# %% [markdown]
# ## Loading the required libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /home/chaitanya/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# ### Loading the data

# %%
data = sns.load_dataset("tips")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### Plotting the violin plots

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x="day", y="total_bill", data=data)
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x="day", y="tip", data=data)
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x="day", y="total_bill", data=data, hue="smoker")
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x="day", y="total_bill", data=data, hue="smoker", linewidth=5)
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x="day", y="total_bill", data=data, hue="smoker", linewidth=2, palette="winter")
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x="smoker", y="total_bill", data=data, order=["Yes", "No"], linewidth=2, palette="winter")
plt.show()
# Out:
# /tmp/ipykernel_11333/2810361094.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="smoker", y="total_bill", data=data, order=["Yes", "No"], linewidth=2, palette="winter")

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x="smoker", y="total_bill", data=data, order=["Yes", "No"], linewidth=2, palette="winter", saturation=0.25)
plt.show()
# Out:
# /tmp/ipykernel_11333/1946564231.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="smoker", y="total_bill", data=data, order=["Yes", "No"], linewidth=2, palette="winter", saturation=0.25)

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x="smoker", y="total_bill", data=data, hue="sex", order=["Yes", "No"], linewidth=2, palette="winter")
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x="smoker", y="total_bill", data=data, hue="sex", order=["Yes", "No"], 
               linewidth=2, palette="winter", split=True, density_norm="width")
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x="total_bill", y="smoker", data=data, hue="sex", order=["Yes", "No"], 
               linewidth=2, palette="winter", split=True, density_norm="width")
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x="smoker", y="total_bill", data=data, hue="sex", order=["Yes", "No"], linewidth=2, palette="winter", inner="quart")
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x="smoker", y="total_bill", data=data, hue="sex", order=["Yes", "No"], linewidth=2, palette="winter", inner="point")
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.violinplot(x=data["total_bill"], palette="Accent")
plt.show()
# Out:
# /tmp/ipykernel_11333/853186855.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=data["total_bill"], palette="Accent")
