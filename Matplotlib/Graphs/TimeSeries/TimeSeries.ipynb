# %% [markdown]
# # Time Series

# %% [markdown]
# Time series plots are used to visualize data points that are collected or recorded over a continuous time interval. These plots help identify trends, patterns, and seasonal variations in the data.

# %% [markdown]
# ## Loading required libraries

# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates

# %% [markdown]
# ### Creating the data

# %%
dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]
y = [0, 1, 3, 4, 6, 5, 7]

# %% [markdown]
# ### Creating a date formatter object.

# %%
date_format = mpl_dates.DateFormatter("%b, %d, %Y")

# %% [markdown]
# ### Plotting a time series graph

# %%
plt.figure(figsize=(20, 10), facecolor="White")
plt.xkcd()
plt.plot_date(dates, y, linestyle="solid")
plt.gcf().autofmt_xdate()
plt.gca().xaxis.set_major_formatter(date_format)
plt.show()
# Out:
# findfont: Font family ['xkcd', 'xkcd Script', 'Humor Sans', 'Comic Neue', 'Comic Sans MS', 'StayPuft'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ### Loading the time-series data from CSV files

# %%
data = pd.read_csv("data.csv")
data["Date"] = pd.to_datetime(data["Date"])
data.sort_values("Date", inplace=True)
data
# Out:
#          Date         Open         High          Low        Close  \
# 0  2019-05-18  7266.080078  8281.660156  7257.259766  8193.139648
# 1  2019-05-19  8193.139648  8193.139648  7591.850098  7998.290039
# 2  2019-05-20  7998.290039  8102.319824  7807.770020  7947.930176
# 3  2019-05-21  7947.930176  8033.759766  7533.660156  7626.890137
# 4  2019-05-22  7626.890137  7971.259766  7478.740234  7876.500000
# 5  2019-05-23  7876.500000  8165.450195  7801.569824  7996.399902
# 6  2019-05-24  7996.399902  8140.819824  7948.680176  8059.129883
# 7  2019-05-25  8059.129883  8779.000000  7894.529785  8726.230469
# 8  2019-05-26  8726.230469  8931.530273  8668.459961  8785.169922
# 9  2019-05-27  8785.169922  8818.709961  8562.200195  8718.849609
# 10 2019-05-28  8718.849609  8760.480469  8444.099609  8664.559570
# 11 2019-05-29  8664.559570  9065.889648  8027.209961  8276.250000
# 12 2019-05-30  8276.250000  8570.780273  8116.000000  8560.080078
# ...

# %% [markdown]
# ### Plotting a time series graph of Bitcoin prices.

# %%
plt.figure(figsize=(20, 10), facecolor="White")
plt.xkcd()
plt.plot_date(data["Date"].values, data["Close"].values, linestyle="solid")
plt.gcf().autofmt_xdate()
plt.title("Bitcoin Prices")
plt.xlabel("Dates")
plt.ylabel("Closing Price")
plt.show()
# Out:
# findfont: Font family ['xkcd', 'xkcd Script', 'Humor Sans', 'Comic Neue', 'Comic Sans MS', 'StayPuft'] not found. Falling back to DejaVu Sans.
